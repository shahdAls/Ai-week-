# %% [markdown]
# ## Task: Predict number of bikers on a given day using linear regression
#
# You are provided with a dataset about Seattle's Fremont Bridge in the form of a csv file.
# The data contains different details about a given day, like weather, temperature and other factors (see the dataframe preview below) for more details. The data also contains how many bikers were observed crossing the brudge that day.
#
# You are provided with the code to download and load the csv file.
#
# Your task is to train a linear regression model which takes in the parameters of the day (you can drop the columns that you think you don't need) and predicts the number of bikers according to those parameters.

# %%
from IPython.display import clear_output
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

from sklearn.datasets import fetch_california_housing

# %%
# Don't modify this code


# %pip install gdown==4.5


clear_output()

# %%
# Download the CSV file.
# !gdown 1_eJU8Y-31_l0oq1sSJT6pROJyo-ufuvD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_eJU8Y-31_l0oq1sSJT6pROJyo-ufuvD
# To: /content/bikers_data.csv
# 100% 213k/213k [00:00<00:00, 15.4MB/s]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bikers_data.csv')

# %%
df.describe()
# Out:
#        Number of bikers          Mon          Tue          Wed          Thu  \
# count       2646.000000  2646.000000  2646.000000  2646.000000  2646.000000
# mean       10972.597128     0.142857     0.142857     0.142857     0.142857
# std         5479.641291     0.349993     0.349993     0.349993     0.349993
# min          152.000000     0.000000     0.000000     0.000000     0.000000
# 25%         7105.000000     0.000000     0.000000     0.000000     0.000000
# 50%        10308.000000     0.000000     0.000000     0.000000     0.000000
# 75%        15274.000000     0.000000     0.000000     0.000000     0.000000
# max        25712.000000     1.000000     1.000000     1.000000     1.000000
#
#                Fri          Sat          Sun      holiday  daylight_hrs  \
# count  2646.000000  2646.000000  2646.000000  2646.000000   2646.000000
# mean      0.142857     0.142857     0.142857     0.027967     11.907412
# std       0.349993     0.349993     0.349993     0.164909      2.615865
# min       0.000000     0.000000     0.000000     0.000000      8.218894
# 25%       0.000000     0.000000     0.000000     0.000000      9.360658
# 50%       0.000000     0.000000     0.000000     0.000000     11.812303
# 75%       0.000000     0.000000     0.000000     0.000000     14.463207
# max       1.000000     1.000000     1.000000     1.000000     15.781095
#
#        Rainfall (in)     Temp (F)      dry day
# count    2646.000000  2646.000000  2646.000000
# mean        0.117305    54.285714     0.568405
# std         0.264038    10.875798     0.495392
# min         0.000000    25.000000     0.000000
# 25%         0.000000    46.000000     0.000000
# 50%         0.000000    53.500000     1.000000
# 75%         0.110000    63.000000     1.000000
# max         3.250000    82.000000     1.000000

# %% [markdown]
# **First preprossing my data by**
# 1. remove cloumn of date
# 2. scale the data  by mean and varince
# after we do that  spelit tha data

# %%
df.columns = df.columns.str.lower()

# %%
# drop date becuase i cant know dell with date type and not nesserliy know
df=df.drop(['Date'],axis=1) # input featuresdata_df.head()
# normlize the data
X = (df - df.mean()) / (df.max() - df.min())

# %%
data_y = df['Number of bikers'] # target
data_x = df.drop(['Number of bikers'], axis=1) # input features
data_x = (df - df.mean()) / (df.max() - df.min())

# %%
data_x.head()
# Out:
#    Number of bikers       Mon       Tue       Wed       Thu       Fri  \
# 0          0.121729 -0.142857 -0.142857  0.857143 -0.142857 -0.142857
# 1          0.114531 -0.142857 -0.142857 -0.142857  0.857143 -0.142857
# 2          0.063357 -0.142857 -0.142857 -0.142857 -0.142857  0.857143
# 3         -0.115360 -0.142857 -0.142857 -0.142857 -0.142857 -0.142857
# 4         -0.094077 -0.142857 -0.142857 -0.142857 -0.142857 -0.142857
#
#         Sat       Sun   holiday  daylight_hrs  Rainfall (in)  Temp (F)  \
# 0 -0.142857 -0.142857 -0.027967     -0.083316      -0.036094  0.030075
# 1 -0.142857 -0.142857 -0.027967     -0.091015      -0.036094  0.038847
# 2 -0.142857 -0.142857 -0.027967     -0.098698      -0.036094  0.091479
# 3  0.857143 -0.142857 -0.027967     -0.106365      -0.036094  0.109023
# 4 -0.142857  0.857143 -0.027967     -0.114015      -0.036094  0.109023
#
#     dry day
# 0  0.431595
# 1  0.431595
# 2  0.431595
# 3  0.431595
# 4  0.431595

# %%
data_y

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data_x , data_y, test_size = 0.2, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

#linear regression model
regressor = LinearRegression()

# Fit the model to the training data
regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = regressor.predict(X_test)

# Evaluate
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 6.515757325720393e-12

# %% [markdown]
# Here I'm try ti build the model by myself but theresoting wrong with type.

# %%
# n -> number of features, m -> number of samples
def initilize_parameters(n):
  w = np.random.rand(1, n)
  b = 0

  return w, b

# %%
def forward(X, w, b): # w --> 1 x n, X --> m x n

  z = np.dot(w, X) + b

  return z

# %%
def cost_function(z, y):
  m = y.shape[1]
  J = (1 / (2 * m) * np.sum(np.square(z - y)))

  return J

# %%
def back_prop(X, y, z):
  m = y.shape[1]

  dz = (1 / m) * (z - y)

  dw = np.dot(dz, X.T)

  db = np.sum(dz)

  return dw, db

# %%
def gradient_descent_update(w, b, dw, db, lr):

  w -=  lr * dw
  b -= lr * db

  return w, b

# %% [markdown]
# Trainig the model

# %%
def linear_regression_model(X_train, y_train, X_test, y_test, lr, epochs):

  n = X_train.shape[0]
  w, b = initilize_parameters(n)

  costs_train = []
  m_train = y_train.shape[1]
  m_test = y_test.shape[1]

  # Training
  for i in range(epochs):

    y_pre = forward(X_train, w, b)
    cost_train = cost_function(y_pre, y_train)

    dw, db = back_prop(X_train, y_train, y_pre)
    w, b = gradient_descent_update(w, b, dw, db, lr)

    # store training cost in a list for plotting purpose
    if i % 10 == 0:
      costs_train.append(cost_train)


    # Testing
    # cost_test
    y_pre_test = forward(X_test, w, b)
    cost_test = cost_function(y_pre_test, y_test)


    # print cost_train, cost_val, MAE_train, MAE_val
    print(f'Epochs {i + 1} / {epochs}: ')
    print(f'Training cost {cost_train} | Testing cost {cost_test}')

  plt.plot(costs_train)
  plt.xlabel('Iterations(per tens)')
  plt.ylabel('Training cost')
  plt.title('Learning rate ' + str(lr))
  plt.show()

# %%
linear_regression_model(X_train, y_train, X_test, y_test, 0.4, 500)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-302-5ad765e958bd> in <cell line: 1>()
# ----> 1 linear_regression_model(X_train, y_train, X_test, y_test, 0.4, 500)
#
# <ipython-input-301-abaea44f2d46> in linear_regression_model(X_train, y_train, X_test, y_test, lr, epochs)
#       5
#       6   costs_train = []
# ----> 7   m_train = y_train.shape[1]
#       8   m_test = y_test.shape[1]
#       9
#
# IndexError: tuple index out of range

# %%
from sklearn.linear_model import LinearRegression

# Create the linear regression model
regressor = LinearRegression()

# Fit the model to the training data
regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = regressor.predict(X_test)

# Evaluate the model
print('MAE:', mean_absolute_error(y_test, y_pred))
